# %%
import pandas as pd
import _sqlite3

from sqlalchemy import create_engine

# %%
df = pd.read_csv('../data/PS_20174392719_1491204439457_log.csv')
print('data loaded')
# Out:
# data loaded

# %%
engine = create_engine('sqlite:///../data/transactions.db', echo=False)

# %%
df.to_sql(
    name='transactions',
    con=engine,
    if_exists='replace',
    index=False
)
print('success')
# Out:
# success
